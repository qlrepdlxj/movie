# %%
#버블차트
library(jsonlite)
library(ggplot2)
setwd('/home/ubuntu/movie/raw_data/daily')
Sys.setenv("plotly_username"="qlrepdlxj")
Sys.setenv("plotly_api_key"="p3j4RHZVUd6lFgKybuvu")
vector = c()
vector2 = c()
vector3 = c()

file_list <- list.files(path='/home/ubuntu/movie/raw_data/daily',pattern = "json")
# file_list[[1]]
for(list in file_list){
    data = fromJSON(list)
    data = data.frame(data)
    data2 = as.numeric(data$boxOfficeResult.dailyBoxOfficeList.audiCnt)
    data3 = as.character(data$boxOfficeResult.showRange[1])
    data3 = substr(data3,1,8)
    sumdata <- sum(data2)
    vector <- append(vector,sumdata)
    vector2 <- append(vector2, data3)
}
vector1 <- vector
total <- cbind(vector2,vector1,vector)
total <- data.frame(total)
# matrix1 <- cbind(vector,vector2)
min <- min(vector)
max <- max(vector)
sizes <- 100*vector/max(vector)

# %%
library(plotly)

# data$State <- as.factor(total$vector)

p <- plot_ly(total, x = ~1:length(vector2), y = ~vector1, type = 'scatter', mode = 'markers',
        marker = list(size = sizes, opacity = 0.5)) %>%
  layout(title = 'Gender Gap in Earnings per University',
         xaxis = list(showgrid = FALSE),
         yaxis = list(showgrid = FALSE))

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="bubble")
chart_link
# Out:
# Found a grid already named: 'bubble Grid'. Since fileopt='overwrite', I'll try to update it
# Found a plot already named: 'bubble'. Since fileopt='overwrite', I'll try to update it

# %%
data = read.csv("/home/ubuntu/movie/data/final/85579.csv")
data = data.frame(data)
# data
x1 <- data$집계날짜
y1 <- data$일일관람객
y2 <- data$검색량
# y3 <- data$리뷰갯수
y4 <- data$평점/10

# %%
ay <- list(
  tickfont = list(color = "red"),
  overlaying = "y",
  side = "right",
  title = ""
)
p <- plot_ly(x = ~1:length(x1), y = y1, name = "일일관람객",type='bar') %>%
  add_lines(x = ~1:length(x1), y = y2, name = "검색량", yaxis = "y2") %>%
  layout(
    title = "", yaxis2 = ay,
    xaxis = list(title="")
  )
# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
 chart_link = api_create(p, filename="part3. 신과함께1")
 chart_link

# %%
ay <- list(
  tickfont = list(color = "red"),
  overlaying = "y",
  side = "right",
  title = ""
)
p <- plot_ly(x = ~1:length(x1), y = y1, name = "일일관람객",type='bar') %>%
  add_lines(x = ~1:length(x1), y = y3 name = "검색량", yaxis = "y3") %>%
  layout(
    title = "", yaxis2 = ay,
    xaxis = list(title="")
  )
# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
 chart_link = api_create(p, filename="part3. 신과함께2")
 chart_link

# %%
## ay <- list(
  tickfont = list(color = "red"),
  overlaying = "y",
  side = "right",
  title = ""
)
p3 <- plot_ly(x = ~1:length(x1), y = y1, name = "일일관람객",type='bar') %>%
  add_lines(x = ~1:length(x1), y = y4, name = "평점", yaxis = ~0:10) %>%
  layout(
    title = "", yaxis2 = ay,
    xaxis = list(title="")
  )
# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
 chart_link = api_create(p3, filename="part3. 신과함께3")
 chart_link

# %%
library(plotly)
packageVersion('plotly')
# data_2007 <- data[which(data$year == 2007),]
# data_2007 <- data_2007[order(data_2007$continent, data_2007$country),]
# slope <- 2.666051223553066e-05
# data_2007$size <- sqrt(data_2007$pop * slope)
colors <- c('#4AC6B7', '#1972A4', '#965F8A', '#FF7070', '#C61951')

p <- plot_ly(total, x = ~vector2, y = ~vector, color = 'blue', size = ~vector, colors = colors,
        type = 'scatter', mode = 'markers', sizes = c(min(vector), max(vector)),
        marker = list(symbol = 'circle', sizemode = 'diameter',
                      line = list(width = 2, color = '#FFFFFF')),
        text = ~paste('audiCnt:', vector)) %>%
  layout(title = 'Life Expectancy v. Per Capita GDP, 2007',
         xaxis = list(title = 'GDP per capita (2000 dollars)',
                      gridcolor = 'rgb(255, 255, 255)',
                      range = c(2.003297660701705, 5.191505530708712),
                      type = 'log',
                      zerolinewidth = 1,
                      ticklen = 5,
                      gridwidth = 2),
         yaxis = list(title = 'Life Expectancy (years)',
                      gridcolor = 'rgb(255, 255, 255)',
                      range = c(36.12621671352166, 91.72921793264332),
                      zerolinewidth = 1,
                      ticklen = 5,
                      gridwith = 2),
         paper_bgcolor = 'rgb(243, 243, 243)',
         plot_bgcolor = 'rgb(243, 243, 243)')

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="bubble-styled")
chart_link
# Out:
# [1] ‘4.8.0’
# Warning message:
# “`as_dictionary()` is soft-deprecated as of rlang 0.3.0.
# Please use `as_data_pronoun()` instead
# This warning is displayed once per session.”Warning message:
# “`new_overscope()` is soft-deprecated as of rlang 0.2.0.
# Please use `new_data_mask()` instead
# This warning is displayed once per session.”Warning message:
# “The `parent` argument of `new_data_mask()` is deprecated.
# The parent of the data mask is determined from either:
#
#   * The `env` argument of `eval_tidy()`
#   * Quosure environments when applicable
# This warning is displayed once per session.”Warning message:
# “`overscope_clean()` is soft-deprecated as of rlang 0.2.0.
# This warning is displayed once per session.”
# Error: `size`/`width` values must be numeric .
# Traceback:
#
# 1. api_create(p, filename = "bubble-styled")
# 2. api_create.plotly(p, filename = "bubble-styled")
# 3. plotly_build(x)
# 4. plotly_build.plotly(x)
# 5. map_size(traces)
# 6. stop("`size`/`width` values must be numeric .", call. = FALSE)

# %%
#크리스마스
library('jsonlite')
data1 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171224.json')
data2 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171225.json')
data1 <- data.frame(data1)
data2 <- data.frame(data2)
a <- data1[,c(7,8,15)]
b <- data2[,c(7,8,15)]
data = merge(a,b,by=c(1), all=FALSE,)
# data
data2 = data[,c(2,3)]
data2[,c(2)] <- as.numeric(data$boxOfficeResult.dailyBoxOfficeList.audiCnt.x) + as.numeric(data$boxOfficeResult.dailyBoxOfficeList.audiCnt.y)
data2
# Out:
#    boxOfficeResult.dailyBoxOfficeList.movieNm.x
# 1  러브 액츄얼리
# 2  신과함께-죄와 벌
# 3  강철비
# 4  스타워즈: 라스트 제다이
# 5  메리와 마녀의 꽃
# 6  뽀로로 극장판 공룡섬 대모험
# 7  극장판 포켓몬스터 너로 정했다!
# 8  더 크리스마스
# 9  몬스터 패밀리
# 10 위대한 쇼맨
#    boxOfficeResult.dailyBoxOfficeList.audiCnt.x
# 1     9984
# 2  2481359
# 3   691584
# 4    82041
# 5    10644
# 6    86481
# 7   189750
# 8    30627
# 9   167148
# 10  304061

# %%
library(plotly)
Sys.setenv("plotly_username"="qlrepdlxj")
Sys.setenv("plotly_api_key"="p3j4RHZVUd6lFgKybuvu")

p <- plot_ly(data2, labels = ~data2[,c(1)], values = ~data2[,c(2)], type = 'pie', hole = 0.5) %>%
  
  layout(title = '',
         xaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE),
         yaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE))

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="크리스마스")
chart_link
# Out:
# Found a grid already named: '크리스마스 Grid'. Since fileopt='overwrite', I'll try to update it
# Found a plot already named: '크리스마스'. Since fileopt='overwrite', I'll try to update it

# %%
#광복절
library('jsonlite')
data1 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170815.json')
data1 <- data.frame(data1)
data2 <- data1[,c(7,8,15)]

data2
# Out:
#    boxOfficeResult.dailyBoxOfficeList.movieCd
# 1  20162869
# 2  20179901
# 3  20162442
# 4  20161081
# 5  20173403
# 6  20178641
# 7  20179226
# 8  20179085
# 9  20161481
# 10 20170124
#    boxOfficeResult.dailyBoxOfficeList.movieNm
# 1  택시운전사
# 2  혹성탈출: 종의 전쟁
# 3  청년경찰
# 4  애나벨 : 인형의 주인
# 5  슈퍼배드 3
# 6  빅풋 주니어
# 7  드래곤 스펠: 마법 꽃의 비밀
# 8  극장판 도라에몽: 진구의 남극 꽁꽁 대모험
# 9  군함도
# 10 명탐정 코난:진홍의 연가
#    boxOfficeResult.dailyBoxOfficeList.audiCnt
# 1  577296
# 2  568300
# 3  415335
# 4  208675
# 5  65587
# 6  34947
# 7  24018
# 8  22670
# 9  18748
# 10 9392

# %%
library(plotly)
Sys.setenv("plotly_username"="qlrepdlxj")
Sys.setenv("plotly_api_key"="p3j4RHZVUd6lFgKybuvu")

p <- plot_ly(data2, labels = ~data2[,c(2)], values = ~data2[,c(3)], type = 'pie', hole = 0.5) %>%
  
  layout(title = '',
         xaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE),
         yaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE))

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="광복절")
chart_link

# %%
#추석
library('jsonlite')
library('DataCombine')
data1 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170930.json')
data2 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171001.json')
data3 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171002.json')
data4 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171003.json')
data5 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171004.json')
data6 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171005.json')
data7 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171006.json')
data8 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171007.json')
data9 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171008.json')
data10 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20171009.json')

data1 <- data.frame(data1)
data2 <- data.frame(data2)
data3 <- data.frame(data3)
data4 <- data.frame(data4)
data5 <- data.frame(data5)
data6 <- data.frame(data6)
data7 <- data.frame(data7)
data8 <- data.frame(data8)
data9 <- data.frame(data9)
data10 <- data.frame(data10)

a <- data1[,c(7,8,15)]
b <- data2[,c(7,8,15)]
c <- data3[,c(7,8,15)]
d <- data4[,c(7,8,15)]
e <- data1[,c(7,8,15)]
f <- data2[,c(7,8,15)]
g <- data3[,c(7,8,15)]
h <- data4[,c(7,8,15)]
i <- data1[,c(7,8,15)]
j <- data2[,c(7,8,15)]

data <- rbind(a,b,c,d,e,f,g,h,i,j)
data2<- data[,c(1,2)]
data2<- unique(data2)
for(i in 1:length(data2$boxOfficeResult.dailyBoxOfficeList.movieCd)){
    data2[i,3]=0
    class(data2[i,3])
    for(j in 1:length(data$boxOfficeResult.dailyBoxOfficeList.movieCd)){
        if(data2[i,1] == data[j,1]){
            data2[i,3] = data2[i,3] + as.numeric(data[j,3])            
        }
    }
}
data2
# Out:
#    boxOfficeResult.dailyBoxOfficeList.movieCd
# 1  20175222
# 2  20174142
# 3  20172142
# 4  20170364
# 5  20154909
# 6  20171090
# 7  20171962
# 8  20172627
# 9  20166132
# 10 20173945
# 28 20165450
# 33 20172742
# 35 20171817
# 36 20170964
# 38 20171369
#    boxOfficeResult.dailyBoxOfficeList.movieNm        V3
# 1  킹스맨: 골든 서클                                 5209124
# 2  아이 캔 스피크                                    2006765
# 3  극장판 요괴워치: 하늘을 나는 고래와 더블세계다냥!  323715
# 4  레고 닌자고 무비                                   260869
# 5  살인자의 기억법                                    214722
# 6  베이비 드라이버                                     99588
# 7  킬러의 보디가드                                    120177
# 8  리틀 프린세스 소피아 : 신비한 섬                    63849
# 9  김광석                                              35472
# 10 인비저블 게스트                                     48397
# 28 남한산성                                           908614
# 33 범죄도시                                           328798
# 35 넛잡 2                                              54458
# 36 딥                                                  49652
# 38 매직울프                                            16664

# %%
library(plotly)
Sys.setenv("plotly_username"="qlrepdlxj")
Sys.setenv("plotly_api_key"="p3j4RHZVUd6lFgKybuvu")

p <- plot_ly(data2, labels = ~data2[,c(2)], values = ~data2[,c(3)], type = 'pie', hole = 0.5) %>%
  
  layout(title = '',
         xaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE),
         yaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE))

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="추석연휴")
chart_link

# %%
#설
library('jsonlite')
library('DataCombine')
data1 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170127.json')
data2 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170128.json')
data3 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170129.json')
data4 <- fromJSON('/home/ubuntu/movie/raw_data/daily/20170130.json')
data1 <- data.frame(data1)
data2 <- data.frame(data2)
data3 <- data.frame(data3)
data4 <- data.frame(data4)
a <- data1[,c(7,8,15)]
b <- data2[,c(7,8,15)]
c <- data3[,c(7,8,15)]
d <- data4[,c(7,8,15)]
# c[2,1]
data <- rbind(a,b,c,d)
data2<- data[,c(1,2)]
data2<- unique(data2)
for(i in 1:length(data2$boxOfficeResult.dailyBoxOfficeList.movieCd)){
    data2[i,3]=0
    class(data2[i,3])
    for(j in 1:length(data$boxOfficeResult.dailyBoxOfficeList.movieCd)){
        if(data2[i,1] == data[j,1]){
            data2[i,3] = data2[i,3] + as.numeric(data[j,3])            
        }
    }
}
data2
# Out:
#    boxOfficeResult.dailyBoxOfficeList.movieCd
# 1  20151228
# 2  20151229
# 3  20165443
# 4  20168688
# 5  20161872
# 6  20163845
# 7  20167904
# 8  20168154
# 9  20167285
# 10 20168366
# 20 20168381
#    boxOfficeResult.dailyBoxOfficeList.movieNm         V3
# 1  공조                                               2696116
# 2  더 킹                                              1680415
# 3  모아나                                              455665
# 4  레지던트 이블: 파멸의 날                            355786
# 5  너의 이름은.                                        213209
# 6  터닝메카드W: 블랙미러의 부활                         84462
# 7  라라랜드                                             82214
# 8  딥워터 호라이즌                                      52630
# 9  짱구는 못말려 극장판: 폭풍수면! 꿈꾸는 세계 대돌격   69658
# 10 바다 탐험대 옥토넛 시즌4: 바다 괴물 대소동           25583
# 20 얼라이드                                              6335

# %%
library(plotly)
Sys.setenv("plotly_username"="qlrepdlxj")
Sys.setenv("plotly_api_key"="p3j4RHZVUd6lFgKybuvu")

p <- plot_ly(data2, labels = ~data2[,c(2)], values = ~data2[,c(3)], type = 'pie', hole = 0.5) %>%
  
  layout(title = '',
         xaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE),
         yaxis = list(showgrid = FALSE, zeroline = FALSE, showticklabels = FALSE))

# Create a shareable link to your chart
# Set up API credentials: https://plot.ly/r/getting-started
chart_link = api_create(p, filename="설연휴")
chart_link
# Out:
# Found a grid already named: '설연휴 Grid'. Since fileopt='overwrite', I'll try to update it
# Found a plot already named: '설연휴'. Since fileopt='overwrite', I'll try to update it
