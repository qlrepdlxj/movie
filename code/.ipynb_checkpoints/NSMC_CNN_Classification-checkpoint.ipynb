# %%
import os
from datetime import datetime
import tensorflow as tf
import numpy as np
import json
from sklearn.model_selection import train_test_split

# %%
FILE_DIR_PATH = '/home/ubuntu/movie/NSMC/data/'
INPUT_TRAIN_DATA_FILE_NAME = 'nsmc_train_input.npy'
LABEL_TRAIN_DATA_FILE_NAME = 'nsmc_train_label.npy'
DATA_CONFIGS_FILE_NAME = 'data_configs.json'

input_data = np.load(open(FILE_DIR_PATH + INPUT_TRAIN_DATA_FILE_NAME, 'rb'))
label_data = np.load(open(FILE_DIR_PATH + LABEL_TRAIN_DATA_FILE_NAME, 'rb'))
prepro_configs = json.load(open(FILE_DIR_PATH + DATA_CONFIGS_FILE_NAME, 'r', encoding="utf-8"))

# %%
TEST_SPLIT = 0.1
RNG_SEED = 13371447

input_train, input_eval, label_train, label_eval = train_test_split(input_data, label_data, test_size=TEST_SPLIT, random_state=RNG_SEED)

# %%
def mapping_fn(X, Y):
    input, label = {'text': X}, Y
    return input, label

def train_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((input_train, label_train))
    dataset = dataset.shuffle(buffer_size=len(input_train))
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.map(mapping_fn)
    dataset = dataset.repeat(count=NUM_EPOCHS)
    iterator = dataset.make_one_shot_iterator()
    
    return iterator.get_next()

def eval_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((input_eval, label_eval))
    dataset = dataset.shuffle(buffer_size=len(input_eval))
    dataset = dataset.batch(16)
    dataset = dataset.map(mapping_fn)
    iterator = dataset.make_one_shot_iterator()
    
    return iterator.get_next()

# %%
# embedding_size = 128
def model_fn(features, labels, mode, params):
    TRAIN = mode == tf.estimator.ModeKeys.TRAIN
    EVAL = mode == tf.estimator.ModeKeys.EVAL
    PREDICT = mode == tf.estimator.ModeKeys.PREDICT

   #embedding layer를 선언합니다.
    input_layer = tf.contrib.layers.embed_sequence(
                    features['text'],
                    vocab_size = vocab_size,
                    embed_dim=128,
                    initializer=params['embedding_initializer']
                    )
    # 현재 모델이 학습모드인지 여부를 확인하는 변수입니다.
    training = (mode == tf.estimator.ModeKeys.TRAIN)
    # embedding layer에 대한 output에 대해 dropout을 취합니다.
    dropout_emb = tf.layers.dropout(inputs=input_layer,
                                  rate=0.2,
                                  training=training)

    #### CNN 구현체 부분 ####
    conv = tf.layers.conv1d(
           inputs=dropout_emb,
           filters=32,
           kernel_size=3,
           padding='same',
           activation=tf.nn.relu)
  
    pool = tf.reduce_max(input_tensor=conv, axis=1) #max-pooling layer


    #Fully-connected layer
    hidden = tf.layers.dense(inputs=pool, units=250, activation=tf.nn.relu)   

    #####################
    dropout_hidden = tf.layers.dropout(inputs=hidden, rate=0.2, training=training)
    logits = tf.layers.dense(inputs=dropout_hidden, units=1)

    #prediction 진행 시, None
    if labels is not None:
        labels = tf.reshape(labels, [-1, 1])
    #최종적으로 학습, 평가, 테스트의 단계로 나누어 활용
    if TRAIN:
        global_step = tf.train.get_global_step()
        loss = tf.losses.sigmoid_cross_entropy(labels, logits)
        train_op = tf.train.AdamOptimizer(0.001).minimize(loss, global_step)

        return tf.estimator.EstimatorSpec(mode=mode, train_op=train_op, loss = loss)

    elif EVAL:
        loss = tf.losses.sigmoid_cross_entropy(labels, logits)
        pred = tf.nn.sigmoid(logits)
        accuracy = tf.metrics.accuracy(labels, tf.round(pred))
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops={'acc': accuracy})

    elif PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions={
                'prob': tf.nn.sigmoid(logits),
            }
        )

# %%
BATCH_SIZE = 16
NUM_EPOCHS = 10
vocab_size = prepro_configs['vocab_size']
embedding_size = 128

params = {'embedding_initializer': tf.random_uniform_initializer(-1.0, 1.0)}

model_dir = os.path.join(os.getcwd(), "/home/ubuntu/movie/NSMC/notebook/checkpoint/cnn_model")
os.makedirs(model_dir, exist_ok=True)

config_tf = tf.estimator.RunConfig()
config_tf._save_checkpoints_steps = 100
config_tf._save_checkpoints_secs = None
config_tf._keep_checkpoint_max =  2
config_tf._log_step_count_steps = 100

est = tf.estimator.Estimator(model_fn, model_dir=model_dir, config=config_tf, params=params)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 2, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9ff5319080>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.logging.set_verbosity(tf.logging.INFO)
print(tf.__version__)
time_start = datetime.utcnow()
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 

est.train(train_input_fn)

time_end = datetime.utcnow()
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# 1.12.0
# Experiment started at 07:22:36
# .......................................
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:loss = 0.7394456, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.7643
# INFO:tensorflow:loss = 0.6711975, step = 101 (3.251 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8655
# INFO:tensorflow:loss = 0.6915049, step = 201 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.859
# INFO:tensorflow:loss = 0.5605813, step = 301 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9669
# INFO:tensorflow:loss = 0.6272048, step = 401 (3.128 sec)
# INFO:tensorflow:Saving checkpoints for 500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.2084
# INFO:tensorflow:loss = 0.68034554, step = 501 (3.204 sec)
# INFO:tensorflow:Saving checkpoints for 600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8152
# INFO:tensorflow:loss = 0.5896074, step = 601 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8386
# INFO:tensorflow:loss = 0.5375873, step = 701 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9296
# INFO:tensorflow:loss = 0.3796597, step = 801 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8815
# INFO:tensorflow:loss = 0.5181112, step = 901 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7451
# INFO:tensorflow:loss = 0.49379405, step = 1001 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 1100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8122
# INFO:tensorflow:loss = 0.6597941, step = 1101 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7786
# INFO:tensorflow:loss = 0.4990562, step = 1201 (3.146 sec)
# INFO:tensorflow:Saving checkpoints for 1300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8302
# INFO:tensorflow:loss = 0.89430934, step = 1301 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 1400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6846
# INFO:tensorflow:loss = 0.51080006, step = 1401 (3.157 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8057
# INFO:tensorflow:loss = 0.446385, step = 1501 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 1600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8375
# INFO:tensorflow:loss = 0.39808267, step = 1601 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 1700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8457
# INFO:tensorflow:loss = 0.61511946, step = 1701 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 1800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.91
# INFO:tensorflow:loss = 0.42206362, step = 1801 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 1900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8285
# INFO:tensorflow:loss = 0.37438613, step = 1901 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.833
# INFO:tensorflow:loss = 0.47999436, step = 2001 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 2100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.901
# INFO:tensorflow:loss = 0.9901725, step = 2101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 2200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9075
# INFO:tensorflow:loss = 0.45699766, step = 2201 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 2300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9089
# INFO:tensorflow:loss = 0.42791966, step = 2301 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 2400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8532
# INFO:tensorflow:loss = 0.5075451, step = 2401 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8736
# INFO:tensorflow:loss = 0.7430264, step = 2501 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 2600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.892
# INFO:tensorflow:loss = 0.47144082, step = 2601 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 2700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8636
# INFO:tensorflow:loss = 0.50194496, step = 2701 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 2800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8254
# INFO:tensorflow:loss = 0.3985561, step = 2801 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 2900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9348
# INFO:tensorflow:loss = 0.336448, step = 2901 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8969
# INFO:tensorflow:loss = 0.47774798, step = 3001 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 3100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7507
# INFO:tensorflow:loss = 0.4758104, step = 3101 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 3200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.858
# INFO:tensorflow:loss = 0.5163801, step = 3201 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 3300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8571
# INFO:tensorflow:loss = 0.37545177, step = 3301 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 3400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9215
# INFO:tensorflow:loss = 0.45207137, step = 3401 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 3500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9412
# INFO:tensorflow:loss = 0.3140066, step = 3501 (3.131 sec)
# INFO:tensorflow:Saving checkpoints for 3600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8522
# INFO:tensorflow:loss = 0.3134915, step = 3601 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 3700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6081
# INFO:tensorflow:loss = 0.4536663, step = 3701 (3.164 sec)
# INFO:tensorflow:Saving checkpoints for 3800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7686
# INFO:tensorflow:loss = 0.2531423, step = 3801 (3.148 sec)
# INFO:tensorflow:Saving checkpoints for 3900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8272
# INFO:tensorflow:loss = 0.48756742, step = 3901 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5907
# INFO:tensorflow:loss = 0.5189577, step = 4001 (3.165 sec)
# INFO:tensorflow:Saving checkpoints for 4100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5644
# INFO:tensorflow:loss = 0.2151687, step = 4101 (3.168 sec)
# INFO:tensorflow:Saving checkpoints for 4200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6677
# INFO:tensorflow:loss = 0.3578643, step = 4201 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 4300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6633
# INFO:tensorflow:loss = 0.42992494, step = 4301 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 4400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6595
# INFO:tensorflow:loss = 0.5665796, step = 4401 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 4500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7126
# INFO:tensorflow:loss = 0.4830713, step = 4501 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 4600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8421
# INFO:tensorflow:loss = 0.67879146, step = 4601 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 4700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9137
# INFO:tensorflow:loss = 0.4916379, step = 4701 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 4800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7479
# INFO:tensorflow:loss = 0.66106117, step = 4801 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 4900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7586
# INFO:tensorflow:loss = 0.30646843, step = 4901 (3.149 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9143
# INFO:tensorflow:loss = 0.30688208, step = 5001 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 5100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9065
# INFO:tensorflow:loss = 0.29660326, step = 5101 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 5200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8876
# INFO:tensorflow:loss = 0.5513823, step = 5201 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 5300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8075
# INFO:tensorflow:loss = 0.41129196, step = 5301 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 5400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7751
# INFO:tensorflow:loss = 0.54963255, step = 5401 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 5500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 29.8269
# INFO:tensorflow:loss = 0.26066047, step = 5501 (3.353 sec)
# INFO:tensorflow:Saving checkpoints for 5600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9351
# INFO:tensorflow:loss = 0.29190108, step = 5601 (3.131 sec)
# INFO:tensorflow:Saving checkpoints for 5700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8513
# INFO:tensorflow:loss = 0.61170614, step = 5701 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 5800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7831
# INFO:tensorflow:loss = 0.17972454, step = 5801 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 5900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9112
# INFO:tensorflow:loss = 0.60978615, step = 5901 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.666
# INFO:tensorflow:loss = 0.6050218, step = 6001 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 6100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8892
# INFO:tensorflow:loss = 0.5530746, step = 6101 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 6200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9118
# INFO:tensorflow:loss = 0.6463576, step = 6201 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 6300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9205
# INFO:tensorflow:loss = 0.3762139, step = 6301 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 6400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8763
# INFO:tensorflow:loss = 0.288531, step = 6401 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 6500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9109
# INFO:tensorflow:loss = 0.54712176, step = 6501 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 6600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9325
# INFO:tensorflow:loss = 0.68512464, step = 6601 (3.131 sec)
# INFO:tensorflow:Saving checkpoints for 6700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8663
# INFO:tensorflow:loss = 0.29056308, step = 6701 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 6800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8626
# INFO:tensorflow:loss = 0.6904591, step = 6801 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 6900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8652
# INFO:tensorflow:loss = 0.38447216, step = 6901 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8388
# INFO:tensorflow:loss = 0.21658964, step = 7001 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 7100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9016
# INFO:tensorflow:loss = 0.4987862, step = 7101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 7200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8091
# INFO:tensorflow:loss = 0.35730892, step = 7201 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 7300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8467
# INFO:tensorflow:loss = 0.1890516, step = 7301 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 7400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8863
# INFO:tensorflow:loss = 0.49078393, step = 7401 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8275
# INFO:tensorflow:loss = 0.483638, step = 7501 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 7600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7831
# INFO:tensorflow:loss = 0.37613615, step = 7601 (3.146 sec)
# INFO:tensorflow:Saving checkpoints for 7700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7726
# INFO:tensorflow:loss = 0.38030502, step = 7701 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 7800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9331
# INFO:tensorflow:loss = 0.308094, step = 7801 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 7900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8909
# INFO:tensorflow:loss = 0.74430037, step = 7901 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8426
# INFO:tensorflow:loss = 0.5570763, step = 8001 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 8100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.871
# INFO:tensorflow:loss = 0.19114798, step = 8101 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 8200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8426
# INFO:tensorflow:loss = 0.40263918, step = 8201 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 8300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7162
# INFO:tensorflow:loss = 0.42264783, step = 8301 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 8400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8887
# INFO:tensorflow:loss = 0.59065443, step = 8401 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 8500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.5318
# INFO:tensorflow:loss = 0.17675444, step = 8501 (3.275 sec)
# INFO:tensorflow:Saving checkpoints for 8600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7938
# INFO:tensorflow:loss = 0.42458507, step = 8601 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 8700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7968
# INFO:tensorflow:loss = 0.26961303, step = 8701 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 8800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.86
# INFO:tensorflow:loss = 0.2173605, step = 8801 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 8900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8223
# INFO:tensorflow:loss = 0.4501238, step = 8901 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.819
# INFO:tensorflow:loss = 0.33271903, step = 9001 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 9100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8951
# INFO:tensorflow:loss = 0.21477258, step = 9101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 9200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9045
# INFO:tensorflow:loss = 0.48529875, step = 9201 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 9300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8786
# INFO:tensorflow:loss = 0.35115898, step = 9301 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 9400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8629
# INFO:tensorflow:loss = 0.39213094, step = 9401 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 9500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9269
# INFO:tensorflow:loss = 0.24911758, step = 9501 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 9600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.873
# INFO:tensorflow:loss = 0.45535082, step = 9601 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 9700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8449
# INFO:tensorflow:loss = 0.39893323, step = 9701 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 9800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9133
# INFO:tensorflow:loss = 0.4736253, step = 9801 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 9900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8131
# INFO:tensorflow:loss = 0.59329605, step = 9901 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.872
# INFO:tensorflow:loss = 0.3058196, step = 10001 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 10100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8992
# INFO:tensorflow:loss = 0.43596804, step = 10101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 10200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7294
# INFO:tensorflow:loss = 0.16880892, step = 10201 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 10300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.739
# INFO:tensorflow:loss = 0.41216633, step = 10301 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 10400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7168
# INFO:tensorflow:loss = 0.36206794, step = 10401 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 10500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.694
# INFO:tensorflow:loss = 0.45656243, step = 10501 (3.155 sec)
# INFO:tensorflow:Saving checkpoints for 10600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9113
# INFO:tensorflow:loss = 0.74332774, step = 10601 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 10700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8687
# INFO:tensorflow:loss = 0.46152863, step = 10701 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 10800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.887
# INFO:tensorflow:loss = 0.68104804, step = 10801 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 10900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9301
# INFO:tensorflow:loss = 0.23191553, step = 10901 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9296
# INFO:tensorflow:loss = 0.51424444, step = 11001 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 11100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8195
# INFO:tensorflow:loss = 0.47315502, step = 11101 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 11200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.822
# INFO:tensorflow:loss = 0.33681905, step = 11201 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 11300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8059
# INFO:tensorflow:loss = 0.36222965, step = 11301 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 11400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8731
# INFO:tensorflow:loss = 0.3038781, step = 11401 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 11500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7623
# INFO:tensorflow:loss = 0.1754818, step = 11501 (3.148 sec)
# INFO:tensorflow:Saving checkpoints for 11600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8865
# INFO:tensorflow:loss = 0.240421, step = 11601 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 11700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8281
# INFO:tensorflow:loss = 0.49201897, step = 11701 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 11800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.814
# INFO:tensorflow:loss = 0.42026338, step = 11801 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 11900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7538
# INFO:tensorflow:loss = 0.39830586, step = 11901 (3.149 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7104
# INFO:tensorflow:loss = 0.24981415, step = 12001 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 12100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8944
# INFO:tensorflow:loss = 0.45312053, step = 12101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 12200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8831
# INFO:tensorflow:loss = 0.41763452, step = 12201 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 12300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8297
# INFO:tensorflow:loss = 0.50909674, step = 12301 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 12400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8929
# INFO:tensorflow:loss = 1.0394415, step = 12401 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 12500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8766
# INFO:tensorflow:loss = 0.2838891, step = 12501 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 12600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8423
# INFO:tensorflow:loss = 0.49157682, step = 12601 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 12700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8597
# INFO:tensorflow:loss = 0.41787684, step = 12701 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 12800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8577
# INFO:tensorflow:loss = 0.36479825, step = 12801 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 12900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9139
# INFO:tensorflow:loss = 0.2347601, step = 12901 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9125
# INFO:tensorflow:loss = 0.2192156, step = 13001 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 13100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8976
# INFO:tensorflow:loss = 0.2700829, step = 13101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 13200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8382
# INFO:tensorflow:loss = 0.4357413, step = 13201 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 13300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8125
# INFO:tensorflow:loss = 0.2847622, step = 13301 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 13400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9003
# INFO:tensorflow:loss = 0.33278814, step = 13401 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 13500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6704
# INFO:tensorflow:loss = 0.30623937, step = 13501 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 13600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8663
# INFO:tensorflow:loss = 0.35003427, step = 13601 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 13700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6732
# INFO:tensorflow:loss = 0.50341856, step = 13701 (3.157 sec)
# INFO:tensorflow:Saving checkpoints for 13800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9281
# INFO:tensorflow:loss = 0.17127681, step = 13801 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 13900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8598
# INFO:tensorflow:loss = 0.31112105, step = 13901 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8734
# INFO:tensorflow:loss = 0.43586516, step = 14001 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 14100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7728
# INFO:tensorflow:loss = 0.4597063, step = 14101 (3.148 sec)
# INFO:tensorflow:Saving checkpoints for 14200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5359
# INFO:tensorflow:loss = 0.28821254, step = 14201 (3.171 sec)
# INFO:tensorflow:Saving checkpoints for 14300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.4307
# INFO:tensorflow:loss = 0.19621319, step = 14301 (3.182 sec)
# INFO:tensorflow:Saving checkpoints for 14400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9033
# INFO:tensorflow:loss = 0.20073064, step = 14401 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 14500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8454
# INFO:tensorflow:loss = 0.26526463, step = 14501 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 14600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8417
# INFO:tensorflow:loss = 0.31526113, step = 14601 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 14700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8397
# INFO:tensorflow:loss = 0.1701514, step = 14701 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 14800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7169
# INFO:tensorflow:loss = 0.34281296, step = 14801 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 14900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8773
# INFO:tensorflow:loss = 0.333601, step = 14901 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8741
# INFO:tensorflow:loss = 0.5463935, step = 15001 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 15100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8724
# INFO:tensorflow:loss = 0.32922256, step = 15101 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 15200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8823
# INFO:tensorflow:loss = 0.42994133, step = 15201 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 15300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8264
# INFO:tensorflow:loss = 0.45050997, step = 15301 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 15400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8576
# INFO:tensorflow:loss = 0.13157293, step = 15401 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 15500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8087
# INFO:tensorflow:loss = 0.33370495, step = 15501 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 15600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8868
# INFO:tensorflow:loss = 0.31816658, step = 15601 (3.136 sec)
# INFO:tensorflow:Saving checkpoints for 15700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8944
# INFO:tensorflow:loss = 0.47438535, step = 15701 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 15800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.889
# INFO:tensorflow:loss = 0.46610796, step = 15801 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 15900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8951
# INFO:tensorflow:loss = 0.39876923, step = 15901 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8735
# INFO:tensorflow:loss = 0.22515121, step = 16001 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 16100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8373
# INFO:tensorflow:loss = 0.39620277, step = 16101 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 16200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9141
# INFO:tensorflow:loss = 0.28915507, step = 16201 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 16300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7949
# INFO:tensorflow:loss = 0.55456054, step = 16301 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 16400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6644
# INFO:tensorflow:loss = 0.54457283, step = 16401 (3.160 sec)
# INFO:tensorflow:Saving checkpoints for 16500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5165
# INFO:tensorflow:loss = 0.511848, step = 16501 (3.171 sec)
# INFO:tensorflow:Saving checkpoints for 16600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7915
# INFO:tensorflow:loss = 0.15503076, step = 16601 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 16700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8337
# INFO:tensorflow:loss = 0.21798518, step = 16701 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 16800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.84
# INFO:tensorflow:loss = 0.31190464, step = 16801 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 16900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.4938
# INFO:tensorflow:loss = 0.32908598, step = 16901 (3.279 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8491
# INFO:tensorflow:loss = 0.28854775, step = 17001 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 17100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.893
# INFO:tensorflow:loss = 0.39352068, step = 17101 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 17200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8611
# INFO:tensorflow:loss = 0.13285941, step = 17201 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 17300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8467
# INFO:tensorflow:loss = 0.18922102, step = 17301 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 17400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8227
# INFO:tensorflow:loss = 0.3320533, step = 17401 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 17500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7961
# INFO:tensorflow:loss = 0.23587191, step = 17501 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 17600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9005
# INFO:tensorflow:loss = 0.2742424, step = 17601 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 17700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9136
# INFO:tensorflow:loss = 0.4222299, step = 17701 (3.133 sec)
# INFO:tensorflow:Saving checkpoints for 17800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7784
# INFO:tensorflow:loss = 0.32296064, step = 17801 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 17900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8154
# INFO:tensorflow:loss = 0.27727616, step = 17901 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9089
# INFO:tensorflow:loss = 0.37544245, step = 18001 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 18100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8154
# INFO:tensorflow:loss = 0.10286417, step = 18101 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 18200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.927
# INFO:tensorflow:loss = 0.15529667, step = 18201 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 18300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6875
# INFO:tensorflow:loss = 0.19681832, step = 18301 (3.156 sec)
# INFO:tensorflow:Saving checkpoints for 18400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7813
# INFO:tensorflow:loss = 0.4288047, step = 18401 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 18500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9041
# INFO:tensorflow:loss = 0.5511817, step = 18501 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 18600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.905
# INFO:tensorflow:loss = 0.092555344, step = 18601 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 18700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8822
# INFO:tensorflow:loss = 0.39270723, step = 18701 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 18800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8382
# INFO:tensorflow:loss = 0.68888235, step = 18801 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 18900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9282
# INFO:tensorflow:loss = 0.32394096, step = 18901 (3.132 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8972
# INFO:tensorflow:loss = 0.23598567, step = 19001 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 19100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8335
# INFO:tensorflow:loss = 0.21149714, step = 19101 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 19200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8228
# INFO:tensorflow:loss = 0.8625065, step = 19201 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 19300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.858
# INFO:tensorflow:loss = 0.049295843, step = 19301 (3.139 sec)
# INFO:tensorflow:Saving checkpoints for 19400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8145
# INFO:tensorflow:loss = 0.29131752, step = 19401 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 19500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7481
# INFO:tensorflow:loss = 0.19053398, step = 19501 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 19600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8956
# INFO:tensorflow:loss = 0.5146517, step = 19601 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 19700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8528
# INFO:tensorflow:loss = 0.2769493, step = 19701 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 19800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6895
# INFO:tensorflow:loss = 0.49186707, step = 19801 (3.156 sec)
# INFO:tensorflow:Saving checkpoints for 19900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.9062
# INFO:tensorflow:loss = 0.34101012, step = 19901 (3.134 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7922
# INFO:tensorflow:loss = 0.14627719, step = 20001 (3.145 sec)
# INFO:tensorflow:Saving checkpoints for 20100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8318
# INFO:tensorflow:loss = 0.44132826, step = 20101 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 20200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8701
# INFO:tensorflow:loss = 0.37983865, step = 20201 (3.137 sec)
# INFO:tensorflow:Saving checkpoints for 20300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8993
# INFO:tensorflow:loss = 0.3477584, step = 20301 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 20400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7363
# INFO:tensorflow:loss = 0.50118935, step = 20401 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 20500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8393
# INFO:tensorflow:loss = 0.26011246, step = 20501 (3.141 sec)
# INFO:tensorflow:Saving checkpoints for 20600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.8404
# INFO:tensorflow:loss = 0.42822394, step = 20601 (3.242 sec)
# INFO:tensorflow:Saving checkpoints for 20700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6955
# INFO:tensorflow:loss = 0.37227815, step = 20701 (3.155 sec)
# INFO:tensorflow:Saving checkpoints for 20800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6349
# INFO:tensorflow:loss = 0.29141042, step = 20801 (3.161 sec)
# INFO:tensorflow:Saving checkpoints for 20900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8692
# INFO:tensorflow:loss = 0.5929125, step = 20901 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 21000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6952
# INFO:tensorflow:loss = 0.3549636, step = 21001 (3.155 sec)
# INFO:tensorflow:Saving checkpoints for 21100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8071
# INFO:tensorflow:loss = 0.50955695, step = 21101 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 21200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7804
# INFO:tensorflow:loss = 0.73701274, step = 21201 (3.149 sec)
# INFO:tensorflow:Saving checkpoints for 21300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# ...
# INFO:tensorflow:global_step/sec: 31.727
# INFO:tensorflow:loss = 0.027772497, step = 77401 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 77500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6871
# INFO:tensorflow:loss = 0.10985395, step = 77501 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 77600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7779
# INFO:tensorflow:loss = 0.39330342, step = 77601 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 77700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7088
# INFO:tensorflow:loss = 0.095332295, step = 77701 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 77800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7246
# INFO:tensorflow:loss = 0.46182942, step = 77801 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 77900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6704
# INFO:tensorflow:loss = 0.16181584, step = 77901 (3.158 sec)
# INFO:tensorflow:Saving checkpoints for 78000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7006
# INFO:tensorflow:loss = 0.15631364, step = 78001 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 78100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7207
# INFO:tensorflow:loss = 0.02032645, step = 78101 (3.155 sec)
# INFO:tensorflow:Saving checkpoints for 78200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8481
# INFO:tensorflow:loss = 0.08221434, step = 78201 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 78300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6936
# INFO:tensorflow:loss = 0.05019959, step = 78301 (3.155 sec)
# INFO:tensorflow:Saving checkpoints for 78400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.645
# INFO:tensorflow:loss = 0.023621239, step = 78401 (3.161 sec)
# INFO:tensorflow:Saving checkpoints for 78500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8414
# INFO:tensorflow:loss = 0.14677225, step = 78501 (3.140 sec)
# INFO:tensorflow:Saving checkpoints for 78600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5553
# INFO:tensorflow:loss = 0.2691133, step = 78601 (3.169 sec)
# INFO:tensorflow:Saving checkpoints for 78700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5778
# INFO:tensorflow:loss = 0.16006768, step = 78701 (3.167 sec)
# INFO:tensorflow:Saving checkpoints for 78800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6057
# INFO:tensorflow:loss = 0.11589606, step = 78801 (3.164 sec)
# INFO:tensorflow:Saving checkpoints for 78900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7249
# INFO:tensorflow:loss = 0.14160302, step = 78901 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 79000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8168
# INFO:tensorflow:loss = 0.4415886, step = 79001 (3.144 sec)
# INFO:tensorflow:Saving checkpoints for 79100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.3841
# INFO:tensorflow:loss = 0.041283555, step = 79101 (3.185 sec)
# INFO:tensorflow:Saving checkpoints for 79200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8213
# INFO:tensorflow:loss = 0.08194832, step = 79201 (3.142 sec)
# INFO:tensorflow:Saving checkpoints for 79300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7491
# INFO:tensorflow:loss = 0.053689837, step = 79301 (3.150 sec)
# INFO:tensorflow:Saving checkpoints for 79400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6072
# INFO:tensorflow:loss = 0.12858926, step = 79401 (3.164 sec)
# INFO:tensorflow:Saving checkpoints for 79500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5498
# INFO:tensorflow:loss = 0.086532325, step = 79501 (3.169 sec)
# INFO:tensorflow:Saving checkpoints for 79600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7713
# INFO:tensorflow:loss = 0.28007317, step = 79601 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 79700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.585
# INFO:tensorflow:loss = 0.029027753, step = 79701 (3.166 sec)
# INFO:tensorflow:Saving checkpoints for 79800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7519
# INFO:tensorflow:loss = 0.3062462, step = 79801 (3.149 sec)
# INFO:tensorflow:Saving checkpoints for 79900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6364
# INFO:tensorflow:loss = 0.1172424, step = 79901 (3.161 sec)
# INFO:tensorflow:Saving checkpoints for 80000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6112
# INFO:tensorflow:loss = 0.29540405, step = 80001 (3.164 sec)
# INFO:tensorflow:Saving checkpoints for 80100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.526
# INFO:tensorflow:loss = 0.4864404, step = 80101 (3.172 sec)
# INFO:tensorflow:Saving checkpoints for 80200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.4981
# INFO:tensorflow:loss = 0.068102986, step = 80201 (3.175 sec)
# INFO:tensorflow:Saving checkpoints for 80300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.704
# INFO:tensorflow:loss = 0.23531286, step = 80301 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 80400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7808
# INFO:tensorflow:loss = 0.038140498, step = 80401 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 80500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7021
# INFO:tensorflow:loss = 0.07303357, step = 80501 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 80600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7325
# INFO:tensorflow:loss = 0.37896517, step = 80601 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 80700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7394
# INFO:tensorflow:loss = 0.10253443, step = 80701 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 80800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.622
# INFO:tensorflow:loss = 0.10676314, step = 80801 (3.162 sec)
# INFO:tensorflow:Saving checkpoints for 80900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6519
# INFO:tensorflow:loss = 0.15346135, step = 80901 (3.159 sec)
# INFO:tensorflow:Saving checkpoints for 81000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7315
# INFO:tensorflow:loss = 0.16063187, step = 81001 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 81100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5923
# INFO:tensorflow:loss = 0.26496726, step = 81101 (3.166 sec)
# INFO:tensorflow:Saving checkpoints for 81200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.812
# INFO:tensorflow:loss = 0.116667844, step = 81201 (3.143 sec)
# INFO:tensorflow:Saving checkpoints for 81300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7534
# INFO:tensorflow:loss = 0.43688253, step = 81301 (3.149 sec)
# INFO:tensorflow:Saving checkpoints for 81400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 29.7673
# INFO:tensorflow:loss = 0.023173977, step = 81401 (3.360 sec)
# INFO:tensorflow:Saving checkpoints for 81500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7282
# INFO:tensorflow:loss = 0.119573966, step = 81501 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 81600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.5706
# INFO:tensorflow:loss = 0.1663672, step = 81601 (3.170 sec)
# INFO:tensorflow:Saving checkpoints for 81700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6877
# INFO:tensorflow:loss = 0.19621935, step = 81701 (3.154 sec)
# INFO:tensorflow:Saving checkpoints for 81800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7786
# INFO:tensorflow:loss = 0.23603573, step = 81801 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 81900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6001
# INFO:tensorflow:loss = 0.35670555, step = 81901 (3.165 sec)
# INFO:tensorflow:Saving checkpoints for 82000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.6733
# INFO:tensorflow:loss = 0.016418112, step = 82001 (3.261 sec)
# INFO:tensorflow:Saving checkpoints for 82100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.2463
# INFO:tensorflow:loss = 0.15165052, step = 82101 (3.306 sec)
# INFO:tensorflow:Saving checkpoints for 82200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 30.3441
# INFO:tensorflow:loss = 0.029207433, step = 82201 (3.294 sec)
# INFO:tensorflow:Saving checkpoints for 82300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.1015
# INFO:tensorflow:loss = 0.2653774, step = 82301 (3.215 sec)
# INFO:tensorflow:Saving checkpoints for 82400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.3209
# INFO:tensorflow:loss = 0.19619074, step = 82401 (3.193 sec)
# INFO:tensorflow:Saving checkpoints for 82500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.2346
# INFO:tensorflow:loss = 0.049378566, step = 82501 (3.202 sec)
# INFO:tensorflow:Saving checkpoints for 82600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.4311
# INFO:tensorflow:loss = 0.12068717, step = 82601 (3.181 sec)
# INFO:tensorflow:Saving checkpoints for 82700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.4838
# INFO:tensorflow:loss = 0.19126672, step = 82701 (3.176 sec)
# INFO:tensorflow:Saving checkpoints for 82800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6724
# INFO:tensorflow:loss = 0.1290463, step = 82801 (3.157 sec)
# INFO:tensorflow:Saving checkpoints for 82900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7937
# INFO:tensorflow:loss = 0.14559717, step = 82901 (3.146 sec)
# INFO:tensorflow:Saving checkpoints for 83000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6445
# INFO:tensorflow:loss = 0.28539884, step = 83001 (3.160 sec)
# INFO:tensorflow:Saving checkpoints for 83100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7752
# INFO:tensorflow:loss = 0.1563676, step = 83101 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 83200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7251
# INFO:tensorflow:loss = 0.16080023, step = 83201 (3.153 sec)
# INFO:tensorflow:Saving checkpoints for 83300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.621
# INFO:tensorflow:loss = 0.11286159, step = 83301 (3.162 sec)
# INFO:tensorflow:Saving checkpoints for 83400 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7288
# INFO:tensorflow:loss = 0.10147131, step = 83401 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 83500 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7333
# INFO:tensorflow:loss = 0.09096873, step = 83501 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 83600 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7812
# INFO:tensorflow:loss = 0.09456983, step = 83601 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 83700 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7812
# INFO:tensorflow:loss = 0.26227435, step = 83701 (3.146 sec)
# INFO:tensorflow:Saving checkpoints for 83800 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.8663
# INFO:tensorflow:loss = 0.09797951, step = 83801 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 83900 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7771
# INFO:tensorflow:loss = 0.45214447, step = 83901 (3.147 sec)
# INFO:tensorflow:Saving checkpoints for 84000 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7249
# INFO:tensorflow:loss = 0.0669921, step = 84001 (3.152 sec)
# INFO:tensorflow:Saving checkpoints for 84100 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.6332
# INFO:tensorflow:loss = 0.1607652, step = 84101 (3.161 sec)
# INFO:tensorflow:Saving checkpoints for 84200 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.7407
# INFO:tensorflow:loss = 0.08107946, step = 84201 (3.151 sec)
# INFO:tensorflow:Saving checkpoints for 84300 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.4686
# INFO:tensorflow:loss = 0.0061731143, step = 84301 (3.178 sec)
# INFO:tensorflow:Saving checkpoints for 84380 into /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.27181146.
# .......................................
# Experiment finished at 08:06:59
#
# Experiment elapsed time: 2663.190631 seconds

# %%
valid = est.evaluate(eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-31-08:06:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt-84380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-31-08:07:00
# INFO:tensorflow:Saving dict for global step 84380: acc = 0.8247333, global_step = 84380, loss = 0.5217535
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84380: /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt-84380

# %%
INPUT_TEST_DATA_FILE_NAME = 'nsmc_test_input.npy'
LABEL_TEST_DATA_FILE_NAME = 'nsmc_test_label.npy'

test_input_data = np.load(open(FILE_DIR_PATH + INPUT_TEST_DATA_FILE_NAME, 'rb'))
test_label_data = np.load(open(FILE_DIR_PATH + LABEL_TEST_DATA_FILE_NAME, 'rb'))

def test_mapping_fn(X):
    input = {'text': X}
    
    return input

#def test_input_fn():
#    dataset = tf.data.Dataset.from_tensor_slices(test_input_data)
#    dataset = dataset.map(mapping_fn)
#    iterator = dataset.make_one_shot_iterator()
#    
#    return iterator.get_next()

def test_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices(test_input_data)
#    dataset = dataset.shuffle(buffer_size=len(input_eval))
    dataset = dataset.batch(16)
    dataset = dataset.map(test_mapping_fn)
    iterator = dataset.make_one_shot_iterator()
    
    return iterator.get_next()

#def eval_input_fn():
#    dataset = tf.data.Dataset.from_tensor_slices((input_eval, label_eval))
#    dataset = dataset.shuffle(buffer_size=len(input_eval))
#    dataset = dataset.batch(16)
#    dataset = dataset.map(mapping_fn)
#    iterator = dataset.make_one_shot_iterator()
# 
#    return iterator.get_next()

prediction = est.predict(test_input_fn)

num_score = []


#prediction을 진행하여, 마지막에 있는 값을 추출 (label 제외)
for i, p in enumerate(prediction):
    num_score.append(p['prob'][0])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /root/NSMC_Sentimental-Analysis/notebook/checkpoint/cnn_model/model.ckpt-84380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
result_label = [] 

for score in num_score:
    if score >= 0.5:
        result_label.append(1)
    else:
        result_label.append(0)

# %%
value = 0
count = 0

for label_predict in result_label:
    if label_predict == test_label_data[count]:
        value = value +1
    count = count + 1 
    
accr = (value / count) * 100

print(accr,"%")
# Out:
# 56.245999999999995 %

# %%
test_label_data[200:210]
# Out:
# array([0, 1, 1, 1, 1, 0, 1, 0, 0, 1])
