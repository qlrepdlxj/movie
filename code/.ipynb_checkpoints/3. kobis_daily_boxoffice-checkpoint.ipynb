# %% [markdown]
# # 3. KOBIS OPEN API
#
# 영화관 입장권 통합 전산망 OPENAPI를 사용하여 일일 박스오피스 자료를 가져오고 JSON파일로 저장
#
# ##  1) 일별 박스오피스
# kobis에서 일별박스오피스 api를 활용하여 movieCd, movieNm, openDt, salesAmt, salesShare, salesInten, salesChange, salesAcc, audiCnt, audiInten, audiChange, audiAcc, scrnCnt, showCnt, CurrentDate, Nation 을 추출
#
# ##  2) 영화 상세정보
# kobis에서 영화상세정보 api를 활용하여 movieCd, movieNm, movieNmEn, movieNmOg, showTm, prdtYear, openDt, prdtStatNm, typeNm, nations, genres, directors, actors 를 추출 = movie_info.txt

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # 3.1 일별 박스오피스

# %% [markdown]
# ### 1) kobis API를 통해 일별 박스오피스 데이터를 받아온다.
# ###     파일은' 해당일자'를 이름으로 지정하고
# ###     JSON 타입으로 저장한다.

# %%
import os
import requests
import json
import calendar
from tqdm import tqdm
from tqdm import tqdm_notebook
from datetime import date, timedelta

key='ad816991534afeaef71f07e7336b0d61'
movie_info_path='/home/ubuntu/miniii_su/movie/'

# %%
def daily_box_office_to_json(start_date,end_date):    
    tmp_date = start_date
#     startDt = int(str(start_date)[0:4]+str(start_date)[5:7]+str(start_date)[8:10])
#     endDt = int(str(end_date)[0:4]+str(end_date)[5:7]+str(end_date)[8:10])
    days = end_date - start_date # 날짜 경과
    for i in tqdm_notebook(range(days.days+1)):
        targetDt = int(str(tmp_date)[0:4]+str(tmp_date)[5:7]+str(tmp_date)[8:10])
        
        if(os.path.isfile(movie_info_path+'raw_data/'+str(targetDt)+'.json')!=1):
            url='http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key='+key+'&targetDt='+str(targetDt)
            res = requests.get(url)
            text = res.text
            d = json.loads(text)
            with open(movie_info_path+'raw_data/daily'+'/'+str(targetDt)+'.json', 'w', encoding="utf-8") as make_file:
                json.dump(d, make_file, ensure_ascii=False, indent="\t")
        tmp_date += timedelta(1)

# %% [markdown]
# ### 3) daliy_box_office_to_json 사용자 함수 실행한다.

# %%
# 2017년 01월 ~ 2018년 02월까지 boxoffice 를 받아온다.
start_date = date(2017,1,1)
end_date = date(2018,2,28)
daily_box_office_to_json(start_date,end_date)
# Out:
# HBox(children=(IntProgress(value=0, max=424), HTML(value='')))

# %% [markdown]
# ### 4) 일별 데이터를 분석할 때 용이하도록 월별로 합친다.

# %%
import pandas as pd
import requests
from datetime import datetime
from datetime import timedelta
import json
from tqdm import tqdm_notebook
from dateutil.relativedelta import relativedelta

key='ad816991534afeaef71f07e7336b0d61'
movie_info_path='/home/ubuntu/miniii_su/movie/'

# %%
def daily_boxoffice(start_date, end_date) :
    
    final_list = []

    for single_date in tqdm_notebook(pd.date_range(start_date, end_date)) :
        targetDt = str(single_date)[0:4]+str(single_date)[5:7]+str(single_date)[8:10]
        with open(movie_info_path+'raw_data/daily/'+str(targetDt)+'.json', 'r', encoding="utf-8") as read_file:
            d = json.load(read_file)

        for item in d["boxOfficeResult"]["dailyBoxOfficeList"] :
            value_list = []
            key_list = []
            for key, value in item.items() :
                key_list.append(key)
                value_list.append(value)

            value_list.append(single_date)
            key_list.append('CurrentDate')
            final_list.append(value_list)

    return pd.DataFrame(final_list, columns=key_list)

# %%
my_date = date(2017, 1, 1)
movie_code_list_all=pd.DataFrame()
for i in tqdm_notebook(range(14)): # 14개월 추출이라서 range(14)
    start_date = my_date + relativedelta(months=i)
    end_date = start_date + relativedelta(months=1) - timedelta(days=1)
    
    daily_boxoffice_data = daily_boxoffice(start_date, end_date)
    startdate=start_date.strftime('%Y%m%d')
    enddate=end_date.strftime('%Y%m%d')
    
    movie_code_list = pd.DataFrame({'movieCd' :daily_boxoffice_data.movieCd.drop_duplicates(), 'movieNm':daily_boxoffice_data.movieNm.drop_duplicates(), 'director':'','Rate' : 0})
    
    
    daily_boxoffice_data.to_csv(movie_info_path+"data/"+"daily_"+startdate+"~"+enddate+".csv", index=False)
    
    
    movie_code_list_all = movie_code_list.append(movie_code_list_all)
    movie_code_list_all = movie_code_list_all.drop_duplicates()
    movie_code_list_all.to_csv(movie_info_path+"data/"+"movie_code_list_all.csv", index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=28), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=28), HTML(value='')))

# %%
movie_code_list_all.head()
# Out:
#     movieCd        movieNm director  Rate
# 0  20168323             염력              0
# 1  20176104      그것만이 내 세상              0
# 2  20178126  인시디어스4: 라스트 키              0
# 3  20179985             코코              0
# 4  20150976      신과함께-죄와 벌              0

# %% [markdown]
# ### 5) 일일 데이터를 하나로 합치기

# %%
# start_date = date(2017,1,1)
# end_date = date(2018,2,28)
# a = daily_boxoffice(start_date, end_date)
# a

# %% [markdown]
# # 3.2 영화 상세정보

# %% [markdown]
# ### 1) kobis API를 통해 영화 정보 데이터를 받아온다.
# ### 파일 이름은 movie_info 이고
# ### csv 파일 형식으로 저장한다.

# %%
#영화데이터  : txt 로 저장 함수 정의
def movie_data(lists) :    
    dict_list = dict()
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json'
    
    for movie in lists :
        #print(movie)
        dic={ 'key' : key, 'movieCd' : movie}        
        req = requests.get(url, params = dic)
        
        dict_list[movie] = req.json()['movieInfoResult']['movieInfo'] #dict_list[movie] 가 있어야 append형식으로 됨. 없으면 마지막것만 추출
    return dict_list

# %%
movie_info=movie_data(movie_code_list_all.movieCd) 
with open(movie_info_path+'raw_data/movie_info/movie_info.txt', 'w', encoding='utf-8') as outfile:   #딕셔너리를 json으로 저장
    json.dump(movie_info, outfile, ensure_ascii=False)

# %% [markdown]
# ### 2)  movie_code_list_all 에 dirctors 삽입

# %%
movie_code_list_all.reset_index(drop=True, inplace=True)
movie_code_list_all
# Out:
#       movieCd                          movieNm director  Rate
# 0    20168323                               염력              0
# 1    20176104                        그것만이 내 세상              0
# 2    20178126                    인시디어스4: 라스트 키              0
# 3    20179985                               코코              0
# 4    20150976                        신과함께-죄와 벌              0
# 5    20175054                    메이즈 러너: 데스 큐어              0
# 6    20178395                           12 솔져스              0
# 7    20170590                             1987              0
# 8    20179228                              마야2              0
# 9    20179205                  조선명탐정: 흡혈괴마의 비밀              0
# 10   20178469                           올 더 머니              0
# 11   19980074                             타이타닉              0
# 12   20189901                            더 포리너              0
# 13   20178672                            패딩턴 2              0
# 14   20189761              터닝메카드W: 반다인의 비밀 특별판              0
# 15   20170841                          리틀 포레스트              0
# 16   20170561                            블랙 팬서              0
# 17   20168250                            골든슬럼버              0
# 18   20176121                  흥부: 글로 세상을 바꾼 자              0
# 19   20078561                     명탐정 코난:감벽의 관              0
# 20   20179462                           위대한 쇼맨              0
# 21   20164844                   불한당: 나쁜 놈들의 세상              0
# 22   20177946                        월요일이 사라졌다              0
# 23   20180542                     50가지 그림자: 해방              0
# 24   20173436                셰이프 오브 워터: 사랑의 모양              0
# 25   20189882                          반딧불이 딘딘              0
# 26   20150969                               궁합              0
# 27   20179731                      나미야 잡화점의 기적              0
# 28   20180341                           레드 스패로              0
# 29   20189861                            더 포스트              0
# ..        ...                              ...      ...   ...
# 294  20161141                     50가지 그림자: 심연              0
# 295  20163580                           그레이트 월              0
# 296  20167362                             더 큐어              0
# 297  20161366                           그래, 가족              0
# 298  20167906                           마이펫 오지              0
# 299  20161723                            싱글라이더              0
# 300  20156562                           루시드 드림              0
# 301  20167922                            핵소 고지              0
# 302  20161725                              마스터              0
# 303  20163183                   로그 원: 스타워즈 스토리              0
# 304  20162025                                씽              0
# 305  20144641                              판도라              0
# 306  20162727                        루돌프와 많이있어              0
# 307  20162183  포켓몬 더 무비 XY&Z 「볼케니온 : 기계왕국의 비밀」              0
# 308  20152371                     당신, 거기 있어줄래요              0
# 309  20165285         극장판 도라에몽: 신 진구의 버스 오브 재팬              0
# 310  19890291                    해리가 샐리를 만났을 때              0
# 311  20161763                      나, 다니엘 블레이크              0
# 312  20163014                     7년-그들이 없는 언론              0
# 313  20161084                             패신저스              0
# 314  20150966                         사랑하기 때문에              0
# 315  20165153              눈의 여왕 3: 눈과 불의 마법대결              0
# 316  20151181                              여교사              0
# 317  20164421                          어쌔신 크리드              0
# 318  20168381                             얼라이드              0
# 319  20168324             반지의 제왕 : 반지원정대 (확장판)              0
# 320  20168664             반지의 제왕 : 두개의 탑 (확장판)              0
# 321  20163186                         단지 세상의 끝              0
# 322  20168689             반지의 제왕 : 왕의 귀환 (확장판)              0
# 323  20168366        바다 탐험대 옥토넛 시즌4: 바다 괴물 대소동              0
#
# [324 rows x 4 columns]

# %%
#movie_info의  director를 뽑아서 movie_code_list에 넣기
movie_info_keys=list(movie_info.keys())
#movie_info_keys

# %%
for i in range(len(movie_code_list_all)):
    with open(movie_info_path+'raw_data/movie_info/movie_info.txt', 'r', encoding="utf-8") as make_file:
        d = json.load(make_file)
    if(d[movie_info_keys[i]]['directors'] != []):
        movie_code_list_all['director'][i]=d[movie_info_keys[i]]['directors'][0]['peopleNm']
        
    else:
        movie_code_list_all['director'][i] = '---'
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
movie_code_list_all
# Out:
#       movieCd                          movieNm    director  Rate
# 0    20168323                               염력         연상호     0
# 1    20176104                        그것만이 내 세상         최성현     0
# 2    20178126                    인시디어스4: 라스트 키      애덤 로비텔     0
# 3    20179985                               코코      리 언크리치     0
# 4    20150976                        신과함께-죄와 벌         김용화     0
# 5    20175054                    메이즈 러너: 데스 큐어        웨스 볼     0
# 6    20178395                           12 솔져스     니콜라이 퓰시     0
# 7    20170590                             1987         장준환     0
# 8    20179228                              마야2     노엘 클리어리     0
# 9    20179205                  조선명탐정: 흡혈괴마의 비밀         김석윤     0
# 10   20178469                           올 더 머니      리들리 스콧     0
# 11   19980074                             타이타닉     제임스 카메론     0
# 12   20189901                            더 포리너       마틴 캠벨     0
# 13   20178672                            패딩턴 2         폴 킹     0
# 14   20189761              터닝메카드W: 반다인의 비밀 특별판         홍헌표     0
# 15   20170841                          리틀 포레스트         임순례     0
# 16   20170561                            블랙 팬서     라이언 쿠글러     0
# 17   20168250                            골든슬럼버         노동석     0
# 18   20176121                  흥부: 글로 세상을 바꾼 자         조근현     0
# 19   20078561                     명탐정 코난:감벽의 관  야마모토 야스이치로     0
# 20   20179462                           위대한 쇼맨    마이클 그레이시     0
# 21   20164844                   불한당: 나쁜 놈들의 세상         변성현     0
# 22   20177946                        월요일이 사라졌다     토미 위르콜라     0
# 23   20180542                     50가지 그림자: 해방      제임스 폴리     0
# 24   20173436                셰이프 오브 워터: 사랑의 모양   기예르모 델 토로     0
# 25   20189882                          반딧불이 딘딘         등위봉     0
# 26   20150969                               궁합         홍창표     0
# 27   20179731                      나미야 잡화점의 기적     히로키 류이치     0
# 28   20180341                           레드 스패로    프란시스 로렌스     0
# 29   20189861                            더 포스트    스티븐 스필버그     0
# ..        ...                              ...         ...   ...
# 294  20161141                     50가지 그림자: 심연      제임스 폴리     0
# 295  20163580                           그레이트 월         장예모     0
# 296  20167362                             더 큐어     고어 버빈스키     0
# 297  20161366                           그래, 가족         마대윤     0
# 298  20167906                           마이펫 오지  알베르토 로드리게즈     0
# 299  20161723                            싱글라이더         이주영     0
# 300  20156562                           루시드 드림         김준성     0
# 301  20167922                            핵소 고지        멜 깁슨     0
# 302  20161725                              마스터         조의석     0
# 303  20163183                   로그 원: 스타워즈 스토리     가렛 에드워즈     0
# 304  20162025                                씽      가스 제닝스     0
# 305  20144641                              판도라         박정우     0
# 306  20162727                        루돌프와 많이있어    유야마 쿠니히코     0
# 307  20162183  포켓몬 더 무비 XY&Z 「볼케니온 : 기계왕국의 비밀」    유야마 쿠니히코     0
# 308  20152371                     당신, 거기 있어줄래요         홍지영     0
# 309  20165285         극장판 도라에몽: 신 진구의 버스 오브 재팬    야쿠와 신노스케     0
# 310  19890291                    해리가 샐리를 만났을 때       롭 라이너     0
# 311  20161763                      나, 다니엘 블레이크        켄 로치     0
# 312  20163014                     7년-그들이 없는 언론         김진혁     0
# 313  20161084                             패신저스       모튼 틸덤     0
# 314  20150966                         사랑하기 때문에         주지홍     0
# 315  20165153              눈의 여왕 3: 눈과 불의 마법대결   알렉세이 트시칠린     0
# 316  20151181                              여교사         김태용     0
# 317  20164421                          어쌔신 크리드      저스틴 커젤     0
# 318  20168381                             얼라이드    로버트 저메키스     0
# 319  20168324             반지의 제왕 : 반지원정대 (확장판)       피터 잭슨     0
# 320  20168664             반지의 제왕 : 두개의 탑 (확장판)       피터 잭슨     0
# 321  20163186                         단지 세상의 끝      자비에 돌란     0
# 322  20168689             반지의 제왕 : 왕의 귀환 (확장판)       피터 잭슨     0
# 323  20168366        바다 탐험대 옥토넛 시즌4: 바다 괴물 대소동      다라 오코넬     0
#
# [324 rows x 4 columns]

# %%
with open('movie_info.txt', 'w', encoding='utf-8') as outfile:   #딕셔너리를 json으로 저장
    json.dump(movie_info, outfile, ensure_ascii=False)
